# %%
import pandas as pd
import os
import numpy as np

# %%
Full_file_data = pd.read_csv('/home/kushik/Kushik/TU Chemnitz/WS 23 24/Research Project/Emissivity/GitHub/ResearchProject/GlobalTemperaturesFull.csv')

# %%
Full_file_data
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
columns = Full_file_data.columns
LAT = columns[1]

# %%
Full_file_data[[LAT]]
# Out:
#       LandAverageTemperature
# 0                      3.034
# 1                      3.083
# 2                      5.626
# 3                      8.490
# 4                     11.573
# ...                      ...
# 3187                  14.755
# 3188                  12.999
# 3189                  10.801
# 3190                   7.433
# 3191                   5.518
#
# [3192 rows x 1 columns]

# %%
numpy_array = Full_file_data[[LAT]].to_numpy()

# %%
numpy_array
# Out:
# array([[ 3.034],
#        [ 3.083],
#        [ 5.626],
#        ...,
#        [10.801],
#        [ 7.433],
#        [ 5.518]])

# %%
numpy_array_non_empty = numpy_array[~np.isnan(numpy_array)]

# %%
print(np.size(numpy_array))
print(np.size(numpy_array_non_empty))
# Out:
# 3192
# 3180

# %%
np.savetxt("GlobalTemperaturesRefined.csv", numpy_array_non_empty, delimiter=",")
